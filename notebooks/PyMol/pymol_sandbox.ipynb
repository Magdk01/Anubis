# %%
import __main__
__main__.pymol_argv = [ 'pymol', '-q' ]

import pymol
import sys, time, os
import pandas as pd

from pymol import cmd
from pymol import stored
pymol.finish_launching()

# %%
cmd.set('fetch_path', cmd.exp_path(r"/home/mangus/Anubis/pdb"), quiet=0)

# %%
output = open("Results_34.txt", "w")
output.write("PDB" + "\t" + "No. a.a." + "\t" + "Glycine" + "\t" + "S.S." + "\t" + "Long SS" + "\t" + "Charge" + "\t"+ "SASA" + "\t" + "No. pos." + "\t" + "No. Surf. pos." + "\t" + "Pos. area" + "\t" + "No. neg." + "\t" + "No. Surf. neg." + "\t" + "Neg. area" + "\t" + "No. hyd." + "\t" + "No. Surf. hyd." + "\t" + "hyd. area" + "\t" + "Alpha" + "\t" + "Beta" + "\t" + "Salt bridges" + "\t" + "H-bonds" + "\n")
 #Load PDB entries
# Out:
# 180

# %%
filename = 'pdb_ids.txt'
# Initialize an empty list to store PDB IDs
PDBs = []

# Open and read the file
with open(filename, 'r') as file:
    for line in file:
        # Strip whitespace and add to the list
        pdb_id = line.strip()
        PDBs.append(pdb_id)

# %%
# Load scripts
cmd.do('''run removealt.py''')
cmd.do('''run findSurfaceResidues.py''')
cmd.do('''run get_raw_distances.py''')

# %%
for pdb in PDBs: 
	
	# Load protein
	cmd.fetch(pdb)

	# Remove hetatm, all but chain A, and alternative locations
	cmd.remove('hetatm')
	cmd.remove('not (chain A or segment A)')
	cmd.do('''removealt''') 

	# Number of amino acids 
	no_aa = cmd.select('name ca') 
	no_aa = str(no_aa) 

	# Number of glycines 
	no_gly = cmd.select('resname GLY and name ca')
	no_gly = str(no_gly)

	# Calculate SASA
	cmd.do('''set dot_solvent, 1''')
	cmd.do('''set dot_density, 2''')
	sasa = cmd.get_area()
	sasa = str(sasa) 

	cmd.do('''findSurfaceResidues''')

	# Find positively charged residues 
	no_pos = cmd.select('resname ARG+LYS and name ca')
	surf_pos = cmd.select('(byres(exposed_res_01 and resname ARG+LYS)) and name ca')
	surf_pos = str(surf_pos)
	surf_pos_all = cmd.get_area('byres(exposed_res_01 and resname ARG+LYS)')
	surf_pos_area = str(surf_pos_all)

	# Find negatively charged residues 
	no_neg = cmd.select('resname GLU+ASP and name ca')
	surf_neg = cmd.select('(byres(exposed_res_01 and resname GLU+ASP)) and name ca')
	surf_neg = str(surf_neg)
	surf_neg_all = cmd.get_area('byres(exposed_res_01 and resname GLU+ASP)')
	surf_neg_area = str(surf_neg_all)

	# Find hydrophobic residues 
	no_hyd = cmd.select('resname ALA+VAL+ILE+LEU+MET+PHE+TYR+TRP and name ca')
	no_hyd = str(no_hyd) 
	surf_hyd = cmd.select('(byres(exposed_res_01 and resname ALA+VAL+ILE+LEU+MET+PHE+TYR+TRP)) and name ca')
	surf_hyd = str(surf_hyd)
	surf_hyd_all = cmd.get_area('byres(exposed_res_01 and resname ALA+VAL+ILE+LEU+MET+PHE+TYR+TRP)')
	surf_hyd_area = str(surf_hyd_all)

	# Charge
	no_pos = cmd.select('resname ARG+LYS and name ca')
	no_neg = cmd.select('resname GLU+ASP and name ca')
	charge = no_pos - no_neg
	charge = str(charge)
	no_neg = str(no_neg) 
	no_pos = str(no_pos) 

	# Number of SS
	no_ssx = cmd.select('CYS/SG and bound_to CYS/SG')
	no_ss = no_ssx/2
	no_ss = str(no_ss)


	# Number of long-range SS
	count = 0
	if no_ssx >= 2:
		cmd.do('''select long_ss, CYS/SG and bound_to CYS/SG''')
		cmd.do('''myspace={'l': []}''')
		cmd.iterate('long_ss', 'l.append(resv)', space=myspace)
		lss = myspace['l']
		cmd.do('''myspace={'d': []}''')

		count = 0
		for i in lss:

			t = []
			a = i

			cmd.select('d', '(not resid %s) and bound_to %s/SG' % (i, i))
			cmd.iterate('d', 't.append(resv)')

			if t:  # Check if t is not empty
				t_i = int("".join(map(str, t)))  # Safely convert elements to string and then to integer
				c = t_i - a

				if abs(c) >= 12:
					count += 1
				# No else needed; if t is empty or the condition is not met, we simply don't increment count

		count = count // 2  # Using integer division
		long_ss = str(count)
	else:
		long_ss = "N"



	stored.s = []
	

	# Secondary structure - percentage
	print(cmd.get_model("n. ca").atom)
	cmd.do('''s = [i.ss for i in cmd.get_model("n. ca").atom]''')
	cmd.iterate("s","stored.s=s")
	# print(cmd.get("s"))
	print(stored.s)

	alp = 100.0*s.count("H")/len(s)
	bet  = 100.0*s.count("S")/len(s)

	alp = str(alp)
	bet  = str(bet)
	
	
	# Salt-bridges (https://sourceforge.net/p/pymol/mailman/message/29141454/)
	cmd.do('''select roi, chain A''')
	cmd.do('''select positive, resn ARG+LYS and not name N+O''')
	cmd.do('''select negative, resn GLU+ASP and not name N+O''')

	cmd.do('''set h_bond_cutoff_center, 5.0''')
	cmd.do('''set h_bond_cutoff_edge, 5.0''')

	cmd.delete('saltbridges')
	cmd.do('''distance saltbridges, roi and negative, roi and positive, mode=2''')
	cmd.hide('label')

	cmd.do('''get_raw_distances''')
	cmd.do('''sb = get_raw_distances('saltbridges')''')
	sb = len(sb)
	sb = str(sb)
	
	cmd.do('''set h_bond_cutoff_center, 3.6''')
	cmd.do('''set h_bond_cutoff_edge, 3.6''')

	# Hydrogen bonds - all
	cmd.do('''distance H_bonds, roi, roi, quiet=1, mode=2, label=0, reset=1''')
	cmd.do('''get_raw_distances''')
	cmd.do('''hb = get_raw_distances('H_bonds')''')
	hb = len(hb)
	hb = str(hb)

	output.write(pdb + "\t" + no_aa + "\t" + no_gly + "\t" + no_ss + "\t" + long_ss + "\t" + charge + "\t" + sasa + "\t" + no_pos + "\t" + surf_pos + "\t" + surf_pos_area + "\t" + no_neg + "\t" + surf_neg + "\t" + surf_neg_area + "\t" + no_hyd + "\t" + surf_hyd + "\t" + surf_hyd_area + "\t" + alp + "\t" + bet + "\t" + sb + "\t" + hb + "\n")
	

	cmd.do('''delete all''')

output.close()
# Out:
# QStandardPaths: wrong permissions on runtime directory /run/user/1000/, 0755 instead of 0700
#  Setting: fetch_path set to /home/mangus/Anubis/pdb.
# PyMOL>run removealt.py
# PyMOL>run findSurfaceResidues.py
# PyMOL>run get_raw_distances.py
# PyMOL>removealt
# PyMOL>set dot_solvent, 1
#  Setting: dot_solvent set to on.
# PyMOL>set dot_density, 2
#  Setting: dot_density set to 2.
# PyMOL>findSurfaceResidues
# Exposed atoms are selected in: exposed_atm_01
# Exposed residues are selected in: exposed_res_01
# No License File - For Evaluation Only (30 days remaining)
# [<chempy.Atom object at 0x7fa9b013bee0>, <chempy.Atom object at 0x7fa9b013bf10>, <chempy.Atom object at 0x7fa9b013bf40>, <chempy.Atom object at 0x7fa9b013bf70>, <chempy.Atom object at 0x7fa9b013bfa0>, <chempy.Atom object at 0x7fa9b013bfd0>, <chempy.Atom object at 0x7fa9b018c040>, <chempy.Atom object at 0x7fa9b018c070>, <chempy.Atom object at 0x7fa9b018c0a0>, <chempy.Atom object at 0x7fa9b018c0d0>, <chempy.Atom object at 0x7fa9b018c100>, <chempy.Atom object at 0x7fa9b018c130>, <chempy.Atom object at 0x7fa9b018c160>, <chempy.Atom object at 0x7fa9b018c190>, <chempy.Atom object at 0x7fa9b018c1c0>, <chempy.Atom object at 0x7fa9b018c1f0>, <chempy.Atom object at 0x7fa9b018c220>, <chempy.Atom object at 0x7fa9b018c250>, <chempy.Atom object at 0x7fa9b018c280>, <chempy.Atom object at 0x7fa9b018c2b0>, <chempy.Atom object at 0x7fa9b018c2e0>, <chempy.Atom object at 0x7fa9b018c310>, <chempy.Atom object at 0x7fa9b018c340>, <chempy.Atom object at 0x7fa9b018c370>, <chempy.Atom object at 0x7fa9b018c3a0>, <chempy.Atom object at 0x7fa9b018c3d0>, <chempy.Atom object at 0x7fa9b018c400>, <chempy.Atom object at 0x7fa9b018c430>, <chempy.Atom object at 0x7fa9b018c460>, <chempy.Atom object at 0x7fa9b018c490>, <chempy.Atom object at 0x7fa9b018c4c0>, <chempy.Atom object at 0x7fa9b018c4f0>, <chempy.Atom object at 0x7fa9b018c520>, <chempy.Atom object at 0x7fa9b018c550>, <chempy.Atom object at 0x7fa9b018c580>, <chempy.Atom object at 0x7fa9b018c5b0>, <chempy.Atom object at 0x7fa9b018c5e0>, <chempy.Atom object at 0x7fa9b018c610>, <chempy.Atom object at 0x7fa9b018c640>, <chempy.Atom object at 0x7fa9b018c670>, <chempy.Atom object at 0x7fa9b018c6a0>, <chempy.Atom object at 0x7fa9b018c6d0>, <chempy.Atom object at 0x7fa9b018c700>, <chempy.Atom object at 0x7fa9b018c730>, <chempy.Atom object at 0x7fa9b018c760>, <chempy.Atom object at 0x7fa9b018c790>, <chempy.Atom object at 0x7fa9b018c7c0>, <chempy.Atom object at 0x7fa9b018c7f0>, <chempy.Atom object at 0x7fa9b018c820>, <chempy.Atom object at 0x7fa9b018c850>, <chempy.Atom object at 0x7fa9b018c880>, <chempy.Atom object at 0x7fa9b018c8b0>, <chempy.Atom object at 0x7fa9b018c8e0>, <chempy.Atom object at 0x7fa9b018c910>, <chempy.Atom object at 0x7fa9b018c940>, <chempy.Atom object at 0x7fa9b018c970>, <chempy.Atom object at 0x7fa9b018c9a0>, <chempy.Atom object at 0x7fa9b018c9d0>, <chempy.Atom object at 0x7fa9b018ca00>, <chempy.Atom object at 0x7fa9b018ca30>, <chempy.Atom object at 0x7fa9b018ca60>, <chempy.Atom object at 0x7fa9b018ca90>, <chempy.Atom object at 0x7fa9b018cac0>, <chempy.Atom object at 0x7fa9b018caf0>, <chempy.Atom object at 0x7fa9b018cb20>, <chempy.Atom object at 0x7fa9b018cb50>, <chempy.Atom object at 0x7fa9b018cb80>, <chempy.Atom object at 0x7fa9b018cbb0>, <chempy.Atom object at 0x7fa9b018cbe0>, <chempy.Atom object at 0x7fa9b018cc10>, <chempy.Atom object at 0x7fa9b018cc40>, <chempy.Atom object at 0x7fa9b018cc70>, <chempy.Atom object at 0x7fa9b018cca0>, <chempy.Atom object at 0x7fa9b018ccd0>, <chempy.Atom object at 0x7fa9b018cd00>, <chempy.Atom object at 0x7fa9b018cd30>, <chempy.Atom object at 0x7fa9b018cd60>, <chempy.Atom object at 0x7fa9b018cd90>, <chempy.Atom object at 0x7fa9b018cdc0>, <chempy.Atom object at 0x7fa9b018cdf0>, <chempy.Atom object at 0x7fa9b018ce20>, <chempy.Atom object at 0x7fa9b018ce50>, <chempy.Atom object at 0x7fa9b018ce80>, <chempy.Atom object at 0x7fa9b018ceb0>, <chempy.Atom object at 0x7fa9b018cee0>, <chempy.Atom object at 0x7fa9b018cf10>, <chempy.Atom object at 0x7fa9b018cf40>, <chempy.Atom object at 0x7fa9b018cf70>, <chempy.Atom object at 0x7fa9b018cfa0>, <chempy.Atom object at 0x7fa9b018cfd0>, <chempy.Atom object at 0x7fa9b018d000>, <chempy.Atom object at 0x7fa9b018d030>, <chempy.Atom object at 0x7fa9b018d060>, <chempy.Atom object at 0x7fa9b018d090>, <chempy.Atom object at 0x7fa9b018d0c0>, <chempy.Atom object at 0x7fa9b018d0f0>, <chempy.Atom object at 0x7fa9b018d120>, <chempy.Atom object at 0x7fa9b018d150>, <chempy.Atom object at 0x7fa9b018d180>, <chempy.Atom object at 0x7fa9b018d1b0>, ...
# PyMOL>s = [i.ss for i in cmd.get_model("n. ca").atom]
#  Detected OpenGL version 4.1. Shaders available.
#  ShaderPrg-Error: vertex shader compilation failed.; name='bezier'
#  ShaderPrg-Error-InfoLog:
# 0:1(10): error: GLSL 4.50 is not supported. Supported versions are: 1.10, 1.20, 1.30, 1.40, 1.50, 3.30, 4.00, 4.10, 1.00 ES, and 3.00 ES
#
#  Detected GLSL version 4.10.
#  ShaderPrg-Error: vertex shader compilation failed.; name='bezier'
#  ShaderPrg-Error-InfoLog:
# 0:1(10): error: GLSL 4.50 is not supported. Supported versions are: 1.10, 1.20, 1.30, 1.40, 1.50, 3.30, 4.00, 4.10, 1.00 ES, and 3.00 ES
#
#
# []
#  cd: now in /home/mangus/Anubis/PyMol
#  Setting: fetch_path set to /home/mangus/Anubis/PyMol.
# PyMOL>run removealt.py
# PyMOL>run findSurfaceResidues.py
# PyMOL>run get_raw_distances.py
# Traceback (most recent call last):
#   File "/home/mangus/Anubis/PyMol/PyMOL_Analysis.py", line 43, in <module>
#     cmd.fetch(pdb)
#   File "/home/mangus/miniconda3/envs/scaling_model/lib/python3.10/site-packages/pymol/importing.py", line 1422, in fetch
#     r = _multifetch(*args)
#   File "/home/mangus/miniconda3/envs/scaling_model/lib/python3.10/site-packages/pymol/importing.py", line 1342, in _multifetch
#     r = _fetch(obj_code, obj_name, state, finish,
#   File "/home/mangus/miniconda3/envs/scaling_model/lib/python3.10/site-packages/pymol/importing.py", line 1278, in _fetch
#     r = _self.load(file, name, state, '',
#   File "/home/mangus/miniconda3/envs/scaling_model/lib/python3.10/site-packages/pymol/importing.py", line 838, in load
#     return func(**kw)
#   File "/home/mangus/miniconda3/envs/scaling_model/lib/python3.10/site-packages/pymol/internal.py", line 368, in _load
#     return _cmd.load(_self._COb, str(oname), str(finfo), contents,
# pymol.CmdException:  Error: loading mmCIF into existing object not supported, please use 'create' to append to an existing object.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 106
#     103 # print(cmd.get("s"))
#     104 print(stored.s)
# --> 106 alp = 100.0*s.count("H")/len(s)
#     107 bet  = 100.0*s.count("S")/len(s)
#     109 alp = str(alp)
#
# NameError: name 's' is not defined

# %%
import os

# %%
os.system('pymol PyMOL_Analysis.py')
# Out:
# QStandardPaths: wrong permissions on runtime directory /run/user/1000/, 0755 instead of 0700
#  PyMOL(TM) 3.0.0 - Incentive Product
#  Copyright (C) Schrodinger, LLC
#
#  This Executable Build integrates and extends Open-Source PyMOL.
# No License File - For Evaluation Only (30 days remaining)
#  Detected OpenGL version 4.1. Shaders available.
#  ShaderPrg-Error: vertex shader compilation failed.; name='bezier'
#  ShaderPrg-Error-InfoLog:
# 0:1(10): error: GLSL 4.50 is not supported. Supported versions are: 1.10, 1.20, 1.30, 1.40, 1.50, 3.30, 4.00, 4.10, 1.00 ES, and 3.00 ES
#
#  Detected GLSL version 4.10.
#  OpenGL graphics engine:
#   GL_VENDOR:   Microsoft Corporation
#   GL_RENDERER: D3D12 (Intel(R) UHD Graphics 770)
#   GL_VERSION:  4.1 (Compatibility Profile) Mesa 23.2.1-1ubuntu3.1~22.04.2
#  ShaderPrg-Error: vertex shader compilation failed.; name='bezier'
#  ShaderPrg-Error-InfoLog:
# 0:1(10): error: GLSL 4.50 is not supported. Supported versions are: 1.10, 1.20, 1.30, 1.40, 1.50, 3.30, 4.00, 4.10, 1.00 ES, and 3.00 ES
#
#
#  Detected 24 CPU cores.  Enabled multithreaded rendering.
#  Setting: fetch_path set to /home/mangus/Anubis/PyMol.
# PyMOL>run removealt.py
# PyMOL>run findSurfaceResidues.py
# PyMOL>run get_raw_distances.py
# PyMOL>removealt
# PyMOL>set dot_solvent, 1
#  Setting: dot_solvent set to on.
# PyMOL>set dot_density, 2
#  Setting: dot_density set to 2.
# PyMOL>findSurfaceResidues
# Exposed atoms are selected in: exposed_atm_01
# Exposed residues are selected in: exposed_res_01
# PyMOL>s = [i.ss for i in cmd.get_model("n. ca").atom]
# PyMOL>select roi, chain A
#  Selector: selection "roi" defined with 883 atoms.
# PyMOL>select positive, resn ARG+LYS and not name N+O
#  Selector: selection "positive" defined with 79 atoms.
# PyMOL>select negative, resn GLU+ASP and not name N+O
#  Selector: selection "negative" defined with 106 atoms.
# PyMOL>set h_bond_cutoff_center, 5.0
#  Setting: h_bond_cutoff_center set to 5.00000.
# PyMOL>set h_bond_cutoff_edge, 5.0
#  Setting: h_bond_cutoff_edge set to 5.00000.
# PyMOL>distance saltbridges, roi and negative, roi and positive, mode=2
#  Executive: object "saltbridges" created.
# PyMOL>get_raw_distances
#  get_raw_distances: (('1a1x', 214), ('1a1x', 176), 3.0375858632302637)
#  get_raw_distances: (('1a1x', 217), ('1a1x', 176), 2.9085057914917694)
#  get_raw_distances: (('1a1x', 333), ('1a1x', 291), 3.2573472179320553)
#  get_raw_distances: (('1a1x', 347), ('1a1x', 273), 2.837969436596525)
#  get_raw_distances: (('1a1x', 349), ('1a1x', 809), 3.4443936302894236)
#  get_raw_distances: (('1a1x', 350), ('1a1x', 273), 3.03837565822667)
#  get_raw_distances: (('1a1x', 678), ('1a1x', 646), 4.628545325354979)
# PyMOL>sb = get_raw_distances('saltbridges')
# PyMOL>set h_bond_cutoff_center, 3.6
#  Setting: h_bond_cutoff_center set to 3.60000.
# PyMOL>set h_bond_cutoff_edge, 3.6
#  Setting: h_bond_cutoff_edge set to 3.60000.
# PyMOL>distance H_bonds, roi, roi, quiet=1, mode=2, label=0, reset=1
# PyMOL>get_raw_distances
#  get_raw_distances: (('1a1x', 214), ('1a1x', 176), 3.0375858632302637)
#  get_raw_distances: (('1a1x', 217), ('1a1x', 176), 2.9085057914917694)
#  get_raw_distances: (('1a1x', 333), ('1a1x', 291), 3.2573472179320553)
#  get_raw_distances: (('1a1x', 347), ('1a1x', 273), 2.837969436596525)
#  get_raw_distances: (('1a1x', 349), ('1a1x', 809), 3.4443936302894236)
#  get_raw_distances: (('1a1x', 350), ('1a1x', 273), 3.03837565822667)
#  get_raw_distances: (('1a1x', 678), ('1a1x', 646), 4.628545325354979)
#  get_raw_distances: (('1a1x', 66), ('1a1x', 74), 2.835346592953774)
#  get_raw_distances: (('1a1x', 134), ('1a1x', 132), 3.452600417823734)
#  get_raw_distances: (('1a1x', 138), ('1a1x', 119), 2.798144647280504)
#  get_raw_distances: (('1a1x', 106), ('1a1x', 141), 2.7696029530680253)
#  get_raw_distances: (('1a1x', 116), ('1a1x', 141), 3.409280793162624)
#  get_raw_distances: (('1a1x', 158), ('1a1x', 88), 2.8379463138158685)
#  get_raw_distances: (('1a1x', 85), ('1a1x', 161), 2.866107278966227)
#  get_raw_distances: (('1a1x', 168), ('1a1x', 113), 3.4954605794091984)
#  get_raw_distances: (('1a1x', 177), ('1a1x', 184), 2.7390972106932696)
#  get_raw_distances: (('1a1x', 67), ('1a1x', 184), 3.3380445393851415)
#  get_raw_distances: (('1a1x', 59), ('1a1x', 185), 3.0117626575676586)
#  get_raw_distances: (('1a1x', 186), ('1a1x', 175), 2.888866393097942)
#  get_raw_distances: (('1a1x', 198), ('1a1x', 175), 3.318735800705323)
#  get_raw_distances: (('1a1x', 198), ('1a1x', 172), 3.0138580757154267)
#  get_raw_distances: (('1a1x', 207), ('1a1x', 175), 3.11778799761859)
#  get_raw_distances: (('1a1x', 169), ('1a1x', 210), 3.0875682029748264)
#  get_raw_distances: (('1a1x', 214), ('1a1x', 176), 3.0375858632302637)
#  get_raw_distances: (('1a1x', 217), ('1a1x', 176), 2.9085057914917694)
#  get_raw_distances: (('1a1x', 225), ('1a1x', 149), 2.8604355734892244)
#  get_raw_distances: (('1a1x', 146), ('1a1x', 228), 2.8589706153374137)
#  get_raw_distances: (('1a1x', 235), ('1a1x', 176), 2.853959690455582)
#  get_raw_distances: (('1a1x', 246), ('1a1x', 137), 2.672140992482182)
#  get_raw_distances: (('1a1x', 283), ('1a1x', 308), 2.771987588819064)
#  get_raw_distances: (('1a1x', 324), ('1a1x', 268), 3.2417022499492347)
#  get_raw_distances: (('1a1x', 265), ('1a1x', 327), 2.9265692982183062)
#  get_raw_distances: (('1a1x', 333), ('1a1x', 291), 3.2573472179320553)
#  get_raw_distances: (('1a1x', 340), ('1a1x', 254), 2.935246122589376)
#  get_raw_distances: (('1a1x', 251), ('1a1x', 343), 2.970423293154671)
#  get_raw_distances: (('1a1x', 347), ('1a1x', 273), 2.837969436596525)
#  get_raw_distances: (('1a1x', 350), ('1a1x', 273), 3.03837565822667)
#  get_raw_distances: (('1a1x', 358), ('1a1x', 242), 2.9707157176205095)
#  get_raw_distances: (('1a1x', 239), ('1a1x', 361), 2.785978536100867)
#  get_raw_distances: (('1a1x', 374), ('1a1x', 221), 2.7808558094587443)
#  get_raw_distances: (('1a1x', 376), ('1a1x', 361), 3.0736540819474123)
#  get_raw_distances: (('1a1x', 376), ('1a1x', 221), 3.3457823272183083)
#  get_raw_distances: (('1a1x', 224), ('1a1x', 379), 2.8249867659634953)
#  get_raw_distances: (('1a1x', 393), ('1a1x', 224), 3.1942222702588343)
#  get_raw_distances: (('1a1x', 115), ('1a1x', 418), 2.9061844693300296)
#  get_raw_distances: (('1a1x', 432), ('1a1x', 109), 2.833388677996846)
#  get_raw_distances: (('1a1x', 461), ('1a1x', 440), 2.934752233172018)
#  get_raw_distances: (('1a1x', 461), ('1a1x', 460), 3.184092124062294)
#  get_raw_distances: (('1a1x', 471), ('1a1x', 440), 3.437578685898705)
#  get_raw_distances: (('1a1x', 471), ('1a1x', 451), 2.9842301763577948)
#  get_raw_distances: (('1a1x', 479), ('1a1x', 451), 2.9820167705203735)
#  get_raw_distances: (('1a1x', 493), ('1a1x', 464), 3.4548633896675893)
#  get_raw_distances: (('1a1x', 494), ('1a1x', 474), 3.1997513110624194)
#  get_raw_distances: (('1a1x', 499), ('1a1x', 132), 2.631917122484884)
#  get_raw_distances: (('1a1x', 507), ('1a1x', 281), 3.248050804596461)
#  get_raw_distances: (('1a1x', 509), ('1a1x', 499), 3.168650184726738)
#  get_raw_distances: (('1a1x', 499), ('1a1x', 512), 3.3901222683894967)
#  get_raw_distances: (('1a1x', 157), ('1a1x', 520), 2.5462219958984327)
#  get_raw_distances: (('1a1x', 99), ('1a1x', 527), 2.9781146582879834)
#  get_raw_distances: (('1a1x', 540), ('1a1x', 80), 2.992444607754052)
#  get_raw_distances: (('1a1x', 77), ('1a1x', 543), 2.934232350531913)
#  get_raw_distances: (('1a1x', 563), ('1a1x', 62), 2.7304606019652176)
#  get_raw_distances: (('1a1x', 599), ('1a1x', 607), 3.3398526851405355)
#  get_raw_distances: (('1a1x', 608), ('1a1x', 574), 3.4974472311232225)
#  get_raw_distances: (('1a1x', 571), ('1a1x', 611), 2.7472947788078104)
#  get_raw_distances: (('1a1x', 615), ('1a1x', 586), 3.1124884102417303)
#  get_raw_distances: (('1a1x', 630), ('1a1x', 55), 2.6929754112709445)
#  get_raw_distances: (('1a1x', 631), ('1a1x', 557), 2.9189076254109954)
#  get_raw_distances: (('1a1x', 554), ('1a1x', 634), 2.8882180104382673)
#  get_raw_distances: (('1a1x', 647), ('1a1x', 535), 3.3039184325128037)
#  get_raw_distances: (('1a1x', 532), ('1a1x', 654), 3.2247523941550447)
#  get_raw_distances: (('1a1x', 524), ('1a1x', 654), 2.8551660614307215)
#  get_raw_distances: (('1a1x', 647), ('1a1x', 654), 2.807274690838438)
#  get_raw_distances: (('1a1x', 655), ('1a1x', 645), 2.8598591521580228)
#  get_raw_distances: (('1a1x', 663), ('1a1x', 642), 3.1788639195726276)
#  get_raw_distances: (('1a1x', 669), ('1a1x', 645), 2.8636477381108993)
#  get_raw_distances: (('1a1x', 639), ('1a1x', 672), 2.9639726973916436)
#  get_raw_distances: (('1a1x', 678), ('1a1x', 662), 3.203029751824356)
#  get_raw_distances: (('1a1x', 688), ('1a1x', 622), 2.7555872622866633)
#  get_raw_distances: (('1a1x', 619), ('1a1x', 691), 2.7969308761226785)
#  get_raw_distances: (('1a1x', 698), ('1a1x', 646), 2.901716624946539)
#  get_raw_distances: (('1a1x', 709), ('1a1x', 602), 2.9177627034748475)
#  get_raw_distances: (('1a1x', 711), ('1a1x', 602), 3.1339266091082294)
#  get_raw_distances: (('1a1x', 709), ('1a1x', 714), 3.548357257064398)
#  get_raw_distances: (('1a1x', 719), ('1a1x', 705), 3.183787000030466)
#  get_raw_distances: (('1a1x', 331), ('1a1x', 727), 2.526139745767142)
#  get_raw_distances: (('1a1x', 756), ('1a1x', 19), 3.28658280171971)
#  get_raw_distances: (('1a1x', 786), ('1a1x', 767), 3.000260875305036)
#  get_raw_distances: (('1a1x', 764), ('1a1x', 789), 2.794015256494965)
#  get_raw_distances: (('1a1x', 367), ('1a1x', 796), 3.033124364745463)
#  get_raw_distances: (('1a1x', 747), ('1a1x', 801), 2.646176205000994)
#  get_raw_distances: (('1a1x', 802), ('1a1x', 751), 2.686791289275165)
#  get_raw_distances: (('1a1x', 748), ('1a1x', 805), 3.0515017325690987)
#  get_raw_distances: (('1a1x', 365), ('1a1x', 809), 2.6848525615283902)
#  get_raw_distances: (('1a1x', 349), ('1a1x', 809), 3.4443936302894236)
#  get_raw_distances: (('1a1x', 811), ('1a1x', 354), 2.714909315604624)
#  get_raw_distances: (('1a1x', 351), ('1a1x', 814), 2.827740957015997)
#  get_raw_distances: (('1a1x', 819), ('1a1x', 731), 2.8858984800157805)
#  get_raw_distances: (('1a1x', 728), ('1a1x', 822), 3.5426575378301743)
#  get_raw_distances: (('1a1x', 719), ('1a1x', 822), 2.708491175352946)
#  get_raw_distances: (('1a1x', 827), ('1a1x', 338), 2.8708450366606777)
#  get_raw_distances: (('1a1x', 335), ('1a1x', 830), 2.8176455322597964)
#  get_raw_distances: (('1a1x', 835), ('1a1x', 705), 2.890766941163207)
#  get_raw_distances: (('1a1x', 702), ('1a1x', 838), 2.7562835151777603)
#  get_raw_distances: (('1a1x', 844), ('1a1x', 319), 2.9959372824614143)
#  get_raw_distances: (('1a1x', 852), ('1a1x', 683), 2.9406374758489107)
# PyMOL>hb = get_raw_distances('H_bonds')
# PyMOL>delete all
# 0
